# %% [markdown]
# # Import package

# %%
import pyhepmc_ng as hepmc ## pip3 install pyhepmc-ng
from particle import PDGID ## pip3 install particle

# %% [markdown]
# # Load hepmc data

# %%
test = hepmc.open("/home/james/Hepmc/QCD-event-Pythia-Herwig-Sherpa/Hepmc/test.hepmc")

# %%
a = test.read()

# %%
a.particles
# Out:
# [GenParticle(FourVector(0, 0, 7000, 7000), mass=0.93827, status=4, id=1, production_vertex=0, end_vertex=-1),
#  GenParticle(FourVector(-3.29319, 0.496547, 1038.08, 1038.09), mass=0, status=61, id=2, production_vertex=-1, end_vertex=-3),
#  GenParticle(FourVector(0.823369, 0.646454, 873.421, 873.422), mass=0, status=61, id=3, production_vertex=-1, end_vertex=-4),
#  GenParticle(FourVector(-1.38306, 0.280289, 18.6025, 18.656), mass=0, status=61, id=4, production_vertex=-1, end_vertex=-5),
#  GenParticle(FourVector(0.12038, -2.09391, 109.56, 109.58), mass=0, status=61, id=5, production_vertex=-1, end_vertex=-6),
#  GenParticle(FourVector(0.341376, 3.15927, 128.341, 128.381), mass=0, status=61, id=6, production_vertex=-1, end_vertex=-7),
#  GenParticle(FourVector(0.877561, -2.32944, 145.317, 145.338), mass=0, status=61, id=7, production_vertex=-1, end_vertex=-8),
#  GenParticle(FourVector(1.33785, 1.7639, 139.369, 139.387), mass=0, status=61, id=8, production_vertex=-1, end_vertex=-9),
# ...

# %% [markdown]
# ## Check the function in Genparticles and PDGID

# %%
dir(a.particles[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'children',
#  'end_vertex',
#  'generated_mass',
#  'id',
#  'in_event',
#  'is_generated_mass_set',
#  'momentum',
#  'parent_event',
#  'parents',
#  'pid',
#  'production_vertex',
#  'status',
#  'unset_generated_mass']

# %%
dir(PDGID)
# Out:
# ['A',
#  'J',
#  'L',
#  'S',
#  'Z',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
# ...

# %%
A = PDGID(a.particles[0].pid)
A
# Out:
# <PDGID: 2212>

# %%
A.charge
# Out:
# 1.0
